# %% [markdown]
# ## Programlama Ödevi -  Nesne Tabanlı Programlama
#
#
#
# ### Proje 1
#
# Kodlama Egzersizimizde yazdığımız Kumanda Sınıfına ek olarak metodlar ve özellikler eklemeye çalışın.

# %%
import random
import time

class Kumanda():

    def __init__(self,tv_durum = "Kapalı",tv_ses = 0,kanal_listesi = ["Trt"],kanal = "Trt"):
        self.tv_durum = tv_durum
        self.tv_ses = tv_ses
        self.kanal_listesi = kanal_listesi
        self.kanal = kanal

    def tv_ac(self):

        if (self.tv_durum == "Açık"):
            print("Televizyon zaten açık....")
        else:
            print("Televizyon Açılıyor...")
            self.tv_durum  = "Açık"

    def tv_kapat(self):

        if (self.tv_durum == "Kapalı"):
            print("Televizyon Zaten Kapalı..")
        else:
            print("Televizyon Kapanıyor....")
            self.tv_durum = "Kapalı"

    def ses_ayarları(self):

        while True:
            cevap =  input("Sesi Azalt: '<'\nSesi Artır: '>'\nÇıkış : çıkış")

            if (cevap == "<"):
                if (self.tv_ses != 0):

                    self.tv_ses -= 1
                    print("Ses:",self.tv_ses)
            elif (cevap == ">"):
                if (self.tv_ses != 31):

                    self.tv_ses += 1

                    print("Ses:",self.tv_ses)
            else:
                print("Ses Güncellendi:",self.tv_ses)
                break
    def kanal_ekle(self,kanal_ismi):
        print("Kanal ekleniyor....")
        time.sleep(1)
        self.kanal_listesi.append(kanal_ismi)
        print("Kanal Eklendi.....")
        
    def kanal_sil(self, kanal_ismi):     #ekstradan eklenen özellik budur.
        if kanal_ismi in self.kanal_listesi:
            self.kanal_listesi.remove(kanal_ismi)
            print(f"{kanal_ismi} kanalı silindi.")
        else:
            print(f"{kanal_ismi} kanalı bulunamadı.")  
            
    def rastgele_kanal(self):
        rastgele = random.randint(0,len(self.kanal_listesi)-1)
        self.kanal = self.kanal_listesi[rastgele]
        print("Şu anki Kanal:" ,self.kanal)
        
    def __len__(self):
        return len(self.kanal_listesi)

    def __str__(self):
        return "Tv Durumu: {}\nTv Ses: {}\nKanal Listesi: {}\nŞu anki kanal: {}\n".format(self.tv_durum,self.tv_ses,self.kanal_listesi,self.kanal)

kumanda = Kumanda()


print("""

Televizyon Uygulaması


1. Tv Aç

2. Tv Kapat

3. Ses Ayarları

4. Kanal Ekle

5. Kanal Sil

6. Kanal Sayısını Öğrenme

7. Rastgele Kanala Geçme

8. Televizyon Bilgileri

Çıkmak için 'q' ya basın.
""")


while True:
    işlem = input("İşlemi Seçiniz:")
    
    if (işlem == "q"):
        print("Program Sonlandırılıyor...")
        break
    elif (işlem == "1"):
        kumanda.tv_ac()
    elif (işlem == "2"):
        kumanda.tv_kapat()
    elif (işlem == "3"):
        kumanda.ses_ayarları()
    elif (işlem == "4"):
        kanal_isimleri = input("Kanal isimlerini ',' ile ayırarak girin:")
        kanal_listesi = kanal_isimleri.split(",")
        
        for eklenecekler in kanal_listesi:
            kumanda.kanal_ekle(eklenecekler)
    elif işlem == "5":
        kanal_ismi = input("Silinecek kanal ismi:")
        kumanda.kanal_sil(kanal_ismi)
    elif (işlem == "6"):
        print("Kanal Sayısı:",len(kumanda))
    elif (işlem == "7"):
        kumanda.rastgele_kanal()
    elif (işlem == "8"):
        print(kumanda)
    else:
        print("Geçersiz İşlem......")
# Out:
# Televizyon Uygulaması
#
#
# 1. Tv Aç
#
# 2. Tv Kapat
#
# 3. Ses Ayarları
#
# 4. Kanal Ekle
#
# 5.Kanal Sil
#
# 6. Kanal Sayısını Öğrenme
#
# 7. Rastgele Kanala Geçme
#
# 8. Televizyon Bilgileri
#
# Çıkmak için 'q' ya basın.
#
# İşlemi Seçiniz:1
# Televizyon Açılıyor...
# İşlemi Seçiniz:4
# Kanal isimlerini ',' ile ayırarak girin:ATV,Show,Fox
# Kanal ekleniyor....
# Kanal Eklendi.....
# Kanal ekleniyor....
# Kanal Eklendi.....
# Kanal ekleniyor....
# Kanal Eklendi.....
# İşlemi Seçiniz:5
# Silinecek kanal ismi:ATV
# ATV kanalı silindi.
# İşlemi Seçiniz:8
# Tv Durumu: Açık
# Tv Ses: 0
# Kanal Listesi: ['Trt', 'Show', 'Fox']
# Şu anki kanal: Trt
#
# İşlemi Seçiniz:1
# Televizyon zaten açık....
# İşlemi Seçiniz:2
# Televizyon Kapanıyor....
# İşlemi Seçiniz:q
# Program Sonlandırılıyor...

# %% [markdown]
# ### Proje 2

# %% [markdown]
# Bir tane "Bilgisayar" sınıfı oluşturarak bu sınıfa metodlar ve özellikler ekleyin ve bu class'ı kullanmaya çalışın.
#
# *Bu sınıfı yazarken öğrendiğimiz özel metodların hepsini tanımlamaya çalışın.*

# %%
class Bilgisayar():
    def __init__(self, marka, model, islemci, ram, depolama):
        self.marka = marka
        self.model = model
        self.islemci = islemci
        self.ram = ram
        self.depolama = depolama
        self.acik = False
        
    def __str__(self):
        # Return kullanmamız gerekli
        return "Marka: {}\nModel: {}\nİşlemci: {}\nRam: {}\nDepolama: {}\nAçık: {}".format(self.marka,self.model,self.islemci,self.ram,self.depolama,self.acik)

    def ac(self):
        if not self.acik:
            self.acik = True
            print(f"{self.marka} {self.model} açıldı.")
        else:
            print(f"{self.marka} {self.model} zaten açık.")

    def kapat(self):
        if self.acik:
            self.acik = False
            print(f"{self.marka} {self.model} kapandı.")
        else:
            print(f"{self.marka} {self.model} zaten kapalı.")

    def ram_yukselt(self, yeni_ram):
        if yeni_ram > self.ram:
            print(f"RAM {self.ram} GB'den {yeni_ram} GB'ye yükseltildi.")
            self.ram = yeni_ram
        else:
            print("Yeni RAM değeri, mevcut RAM değerinden büyük olmalıdır.")

    def depolama_yukselt(self, yeni_depolama):
        if yeni_depolama > self.depolama:
            print(f"Depolama {self.depolama} GB'den {yeni_depolama} GB'ye yükseltildi.")
            self.depolama = yeni_depolama
        else:
            print("Yeni depolama değeri, mevcut depolama değerinden büyük olmalıdır.")

            
bilgisayar = Bilgisayar("Lenovo", "ThinkPad", "Intel i7", 8, 256)
print(bilgisayar)
bilgisayar.ac()
bilgisayar.ram_yukselt(16)
bilgisayar.depolama_yukselt(512)
bilgisayar.kapat()
print(bilgisayar)
# Out:
# Marka: Lenovo
# Model: ThinkPad
# İşlemci: Intel i7
# Ram: 8
# Depolama: 256
# Açık: False
# Lenovo ThinkPad açıldı.
# RAM 8 GB'den 16 GB'ye yükseltildi.
# Depolama 256 GB'den 512 GB'ye yükseltildi.
# Lenovo ThinkPad kapandı.
# Marka: Lenovo
# Model: ThinkPad
# İşlemci: Intel i7
# Ram: 16
# Depolama: 512
# Açık: False

# %% [markdown]
# ### Proje 3

# %% [markdown]
# Bu projede ise 4 tane sınıfı oluşturun.
#
# *Hayvan Sınıfı ------> Bütün hayvanların ortak özelliklerinin toplandığı sınıf olacak.*
#
# *Köpek Sınıfı  ------> Bu sınıf, hayvan sınıfından miras alan bir sınıf olacak. Ayrıca bu sınıfa köpeklere ait ek özellikler ve metodlar ekleyin.*
#
# *Kuş Sınıfı  ------> Bu sınıf, hayvan sınıfından miras alan bir sınıf olacak. Ayrıca bu sınıfa kuşlara ait ek özellikler ve metodlar ekleyin.*
#
# *At Sınıfı   ------> Bu sınıf, hayvan sınıfından miras alan bir sınıf olacak. Ayrıca bu sınıfa atlara ait ek özellikler ve metodlar ekleyin.*

# %%
class Hayvan():
    def __init__(self, isim, yas, tur):
        self.isim = isim
        self.yas = yas
        self.tur = tur

    def ses_cikar(self):
        pass

    def bilgileri_goster(self):
        print(f"İsim: {self.isim}")
        print(f"Yaş: {self.yas}")
        print(f"Tür: {self.tur}")

        
class Kopek(Hayvan):
    def __init__(self, isim, yas, tur, cins):
        super().__init__(isim, yas, tur)
        self.cins = cins

    def ses_cikar(self):
        print("Hav hav!")

    def bilgileri_goster(self):
        super().bilgileri_goster()
        print(f"Cins: {self.cins}")

    def kuyruk_salla(self):
        print(f"{self.isim} kuyruğunu sallıyor.")

            
class Kus(Hayvan):
    def __init__(self, isim, yas, tur, kanat_acikligi):
        super().__init__(isim, yas, tur)
        self.kanat_acikligi = kanat_acikligi

    def ses_cikar(self):
        print("Cik cik!")

    def bilgileri_goster(self):
        super().bilgileri_goster()
        print(f"Kanat Açıklığı: {self.kanat_acikligi} cm")

    def uc(self):
        print(f"{self.isim} uçuyor.")

              
class At(Hayvan):
    def __init__(self, isim, yas, tur, yetenek):
        super().__init__(isim, yas, tur)
        self.yetenek = yetenek

    def ses_cikar(self):
        print("İhihihi!")

    def bilgileri_goster(self):
        super().bilgileri_goster()
        print(f"Yetenek: {self.yetenek}")

    def kos(self):
        print(f"{self.isim} koşuyor.")

        
kopek1 = Kopek("Karabaş", 5, "Köpek", "Golden Retriever")
kopek1.bilgileri_goster()
kopek1.ses_cikar()
kopek1.kuyruk_salla()

print()

kus1 = Kus("Maviş", 2, "Kuş", 30)
kus1.bilgileri_goster()
kus1.ses_cikar()
kus1.uc()

print()

at1 = At("Şahbatur", 7, "At", "Engel Atlama")
at1.bilgileri_goster()
at1.ses_cikar()
at1.kos()
# Out:
# İsim: Karabaş
# Yaş: 5
# Tür: Köpek
# Cins: Golden Retriever
# Hav hav!
# Karabaş kuyruğunu sallıyor.
#
# İsim: Maviş
# Yaş: 2
# Tür: Kuş
# Kanat Açıklığı: 30 cm
# Cik cik!
# Maviş uçuyor.
#
# İsim: Şahbatur
# Yaş: 7
# Tür: At
# Yetenek: Engel Atlama
# İhihihi!
# Şahbatur koşuyor.
